# %% [markdown]
# # IDB

# %%
pip install idbsocialdatapy
# Out:
# Collecting idbsocialdatapy
#   Downloading idbsocialdatapy-0.2.1-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: pandas>=1.3.5 in /Users/anapreciado/Desktop/github_repos/dataccion-agent/.venv/lib/python3.12/site-packages (from idbsocialdatapy) (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in /Users/anapreciado/Desktop/github_repos/dataccion-agent/.venv/lib/python3.12/site-packages (from pandas>=1.3.5->idbsocialdatapy) (2.4.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/anapreciado/Desktop/github_repos/dataccion-agent/.venv/lib/python3.12/site-packages (from pandas>=1.3.5->idbsocialdatapy) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/anapreciado/Desktop/github_repos/dataccion-agent/.venv/lib/python3.12/site-packages (from pandas>=1.3.5->idbsocialdatapy) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/anapreciado/Desktop/github_repos/dataccion-agent/.venv/lib/python3.12/site-packages (from pandas>=1.3.5->idbsocialdatapy) (2025.3)
# Requirement already satisfied: six>=1.5 in /Users/anapreciado/Desktop/github_repos/dataccion-agent/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.5->idbsocialdatapy) (1.17.0)
# Downloading idbsocialdatapy-0.2.1-py3-none-any.whl (10.0 kB)
# Installing collected packages: idbsocialdatapy
# Successfully installed idbsocialdatapy-0.2.1
#
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import idbsocialdatapy as idb
poverty = idb.query_indicator(indicator = 'pobreza') # define indicator to consult 
                          #categories = 'sex', # define category/ies I want to see in the indicator
                          #countries = 'COL,BRA,MEX', #define countries you want data from
                          #yearstart = '2005', # starting period
                          #yearend = '2021') # ending period
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/Desktop/github_repos/dataccion-agent/.venv/lib/python3.12/site-packages/requests/models.py:976, in Response.json(self, **kwargs)
#     975 try:
# --> 976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File /opt/homebrew/Cellar/python@3.12/3.12.12_2/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.12_2/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/decoder.py:338, in JSONDecoder.decode(self, s, _w)
#     334 """Return the Python representation of ``s`` (a ``str`` instance
#     335 containing a JSON document).
#     336
#     337 """
# --> 338 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     339 end = _w(s, end).end()
#
# File /opt/homebrew/Cellar/python@3.12/3.12.12_2/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/decoder.py:356, in JSONDecoder.raw_decode(self, s, idx)
#     355 except StopIteration as err:
# --> 356     raise JSONDecodeError("Expecting value", s, err.value) from None
#     357 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[5], line 2
#       1 import idbsocialdatapy as idb
# ----> 2 poverty = idb.query_indicator(indicator = 'pobreza') # define indicator to consult
#       3                           #categories = 'sex', # define category/ies I want to see in the indicator
#       4                           #countries = 'COL,BRA,MEX', #define countries you want data from
#       5                           #yearstart = '2005', # starting period
#
# File ~/Desktop/github_repos/dataccion-agent/.venv/lib/python3.12/site-packages/idbsocialdatapy/core.py:135, in query_indicator(indicator, categories, countries, yearstart, yearend, year, latest)
#     132 if latest:
#     133     url = url + "&latest"
# --> 135 json_data = requests.get(url).json()["data"]
#     136 data = pd.DataFrame(json_data)
#     137 if data.empty:
#
# File ~/Desktop/github_repos/dataccion-agent/.venv/lib/python3.12/site-packages/requests/models.py:980, in Response.json(self, **kwargs)
#     976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 980     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
