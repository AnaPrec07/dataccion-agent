# %% [markdown]
# # Play with modules

# %%
import sys
import os
sys.path.append(os.getcwd())
from pdf_loader import PDFLoader
from retriever import Retriever

# %%
pdf_loader = PDFLoader(
        bucket_name="dataccion-country-reports",
        chunk_size=800,
        chunk_overlap=150
)
# Out:
# /Users/anapreciado/Desktop/github_repos/dataccion-agent/.venv/lib/python3.12/site-packages/google/auth/_default.py:114: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# /Users/anapreciado/Desktop/github_repos/dataccion-agent/.venv/lib/python3.12/site-packages/google/auth/_default.py:114: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %% [markdown]
# # Load PDFs

# %%
# list PDFs
pdf_loader.list_pdfs()

# load and split
splitted_chunks = pdf_loader.load_and_split()
print(splitted_chunks)
# Out:
# ['2024-pdf.pdf',
#  'current_situation/What-Is-the-Labor-Market-Like-for-Women-in-Latin-America-and-the_Caribbean.pdf',
#  'forward_looking/The-Future-of-Work-in-Latin-America-and-the-Caribbean-What-will-The-Labor-Market-Be-Like-for-Women-Print-version.pdf',
#  'proposals/Closing-Gender-Gaps-in-the-World-of-Work-Central-America-Mexico-Panama-and-the-Dominican-Republic.pdf']

# %%
print(splitted_chunks)
# Out:
# [Chunk(source='2024-pdf.pdf', page=0, chunk_index=0, text='Women in\nthe Workplace\n2024\nTHE 10TH ANNIVERSARY REPORT', metadata={'source': '2024-pdf.pdf', 'page': 0}), Chunk(source='2024-pdf.pdf', page=1, chunk_index=0, text='2  |  WOMEN IN THE WORKPLACE: ABOUT THE STUDY / TABLE OF CONTENTS\n4\n13\n30\n45\n3\nWomen in the Workplace is the largest study on the state of women in corporate \nAmerica.1 For this 10th anniversary report, we analyzed data from the past decade to \nbetter understand progress, decline, and stagnation in women’s representation and \nexperiences. Over the last 10 years, more than 1,000 companies have participated in \nthe study and over 480,000 people were surveyed on their workplace experiences. \nIn 2024, we collected information from 281 participating organizations employing over \n10 million people, surveyed more than 15,000 employees, and conducted interviews \nwith people of diverse identities, including women of color, LGBTQ+ women, and women', metadata
# ...

# %% [markdown]
# # Go through Retriever

# %%
retriever = Retriever(
        project_id="porygon-dataccion",
        bucket_name="dataccion-country-reports",
        location= "us-east4"
)
# Out:
# /Users/anapreciado/Desktop/github_repos/dataccion-agent/.venv/lib/python3.12/site-packages/google/auth/_default.py:114: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# /Users/anapreciado/Desktop/github_repos/dataccion-agent/.venv/lib/python3.12/site-packages/google/auth/_default.py:114: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %%
retriever.ingest()
# Out:
# /Users/anapreciado/Desktop/github_repos/dataccion-agent/.venv/lib/python3.12/site-packages/google/auth/_default.py:114: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# 841

# %%
answers_context = retriever.retrieve_context(
    query="what is the main barrier women face in the job market?"
)

# %%
print(len(answers_context))
print(type(answers_context))
print(answers_context)
# Out:
# 4203
# <class 'str'>
# [Source: 2024-pdf.pdf, page 8]
# Women continue to face barriers at the beginning of the pipeline
# Women remain less likely than men to be hired into entry-level roles, which leaves them underrepresented
# from the very beginning. Then, at the ﬁrst critical step up to manager, women are far less likely to get
# promoted, and this is not improving. For every 100 men promoted to manager in 2018, 79 women were
# promoted. And this year, just 81 women were. As a result of this “broken rung,” men signiﬁcantly outnumber
# women at the manager level, which makes it nearly impossible for
# companies to support sustained progress at more senior levels.
# Women are still underrepresented from the get-go …9
# … And continue to lose the most ground at the ﬁrst step up to manager
#
# ---
#
# [Source: current_situation/What-Is-the-Labor-Market-Like-for-Women-in-Latin-America-and-the_Caribbean.pdf, page 3]
# Diversity Division. V. Title. VI.Series.
# IDB-PB-385
# ...

# %%
answers = retriever.retrieve(
    query="what is the main barrier women face in the job market?"
)

# %%
print(len(answers))
print(type(answers))
print(answers)
# Out:
# 5
# <class 'list'>
# ...
